# %%
#Loading Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("Cafe_Data_MRA.xlsx")

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145830 entries, 0 to 145829
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          145830 non-null  datetime64[ns]
#  1   Bill Number   145830 non-null  object
#  2   Item Desc     145830 non-null  object
#  3   Time          145830 non-null  object
#  4   Quantity      145830 non-null  int64
#  5   Rate          145830 non-null  float64
#  6   Tax           145830 non-null  float64
#  7   Discount      145830 non-null  float64
#  8   Total         145830 non-null  float64
#  9   Category      145830 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 11.1+ MB

# %%
df.shape
# Out:
# (145830, 10)

# %%
df.describe()
# Out:
#             Quantity           Rate            Tax       Discount  \
# count  145830.000000  145830.000000  145830.000000  145830.000000
# mean        1.121299     161.782259      48.929061       0.095079
# std         0.477237     102.244631      40.272851       3.720735
# min         1.000000       0.010000       0.000000       0.000000
# 25%         1.000000      95.000000      22.560000       0.000000
# 50%         1.000000     125.000000      32.060000       0.000000
# 75%         1.000000     225.000000      72.000000       0.000000
# max        30.000000    2100.000000    2731.250000     825.000000
#
#                Total
# count  145830.000000
# mean      224.959852
# std       164.960776
# min         0.010000
# 25%       117.560000
# 50%       167.060000
# 75%       315.000000
# max     14231.250000

# %%
df.isnull().sum()
# Out:
# Date            0
# Bill Number     0
# Item Desc       0
# Time            0
# Quantity        0
# Rate            0
# Tax             0
# Discount        0
# Total           0
# Category        0
# dtype: int64

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 680
#              Date Bill Number                        Item Desc      Time  \
# 198    2010-04-01     G0470211  B.M.T. PANINI                   19:42:27
# 199    2010-04-01     G0470211  B.M.T. PANINI                   19:42:27
# 244    2010-04-01     G0470270  B.M.T. PANINI                   00:08:20
# 551    2010-05-01     G0474965  PHILLYCREAM CHEESE &CHILLY PAN  13:33:51
# 588    2010-05-01     G0475009  B.M.T. PANINI                   17:12:21
# ...           ...          ...                             ...       ...
# 144615 2010-10-31     G0506562  DOPPIO                          19:08:48
# 144727 2010-10-31     G0506566  CHEESE CAKE OF THE WEEK         19:20:52
# 145129 2010-12-31     G0517963  CAPPUCCINO                      20:50:13
# 145255 2010-12-31     G0517869  PHILLYCREAM CHEESE &CHILLY PAN  15:12:41
# 145315 2010-12-31     G0518126  PHILLYCREAM CHEESE &CHILLY PAN  05:02:24
#
#         Quantity   Rate    Tax  Discount   Total  Category
# 198            1  105.0  24.94       0.0  129.94      FOOD
# 199            1  105.0  24.94       0.0  129.94      FOOD
# 244            1  105.0  24.94       0.0  129.94      FOOD
# 551            1  105.0  24.94       0.0  129.94      FOOD
# 588            1  105.0  24.94       0.0  129.94      FOOD
# ...          ...    ...    ...       ...     ...       ...
# 144615         1   60.0  14.25       0.0   74.25  BEVERAGE
# 144727         1  105.0  24.94       0.0  129.94      FOOD
# 145129         1   60.0  14.25       0.0   74.25  BEVERAGE
# 145255         1  105.0  24.94       0.0  129.94      FOOD
# 145315         1  105.0  24.94       0.0  129.94      FOOD
#
# [680 rows x 10 columns]

# %%
df['Item Desc'].value_counts()
# Out:
# NIRVANA HOOKAH SINGLE                   8553
# MINT FLAVOUR SINGLE                     5817
# CAPPUCCINO                              5495
# GREAT LAKES SHAKE                       4895
# SAMBUCA                                 4425
#                                         ...
# UDAIPUR LILY                               1
# ADD BUTTERED TOAST                         1
# DECAFFINATE COFFEE FRAPPE                  1
# INDIA KINGS OCEAN BLUE                     1
# ZINZI WHITE (BTL)                          1
# Name: Item Desc, Length: 580, dtype: int64

# %% [raw]
# There are 580 items in the menu.

# %%
df['Category'].value_counts()
# Out:
# FOOD                57023
# BEVERAGE            43573
# TOBACCO             36496
# LIQUOR               6200
# MISC                 1187
# WINES                 809
# MERCHANDISE           487
# LIQUOR & TOBACCO       54
# LIQUOR                  1
# Name: Category, dtype: int64

# %%
# Category Liquor shows up twice due to the presence of a space.
df[['Category']] = df[['Category']].replace('LIQUOR ','LIQUOR')

# %%
df_1 = df.groupby(['Category','Item Desc']).agg({'Total':['sum']})

# %%
df_1.sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                                  Total
#                                                    sum
# Category    Item Desc
# TOBACCO     NIRVANA HOOKAH SINGLE           2953134.60
#             SAMBUCA                         2291058.00
#             MINT FLAVOUR SINGLE             1840501.00
#             CALCUTTA MINT                   1640860.40
#             N R G  HOOKAH                   1193015.40
# ...                                                ...
# MERCHANDISE MUGS - PLAIN COLOUR                  75.38
#             DIP BOWL                             67.50
#             CUTTING GLASS                        27.00
# FOOD        ADD BUTTERED TOAST                   18.56
#             MOTHERS DAY SPL                       0.05
#
# [602 rows x 1 columns]

# %%
df_1.head()
# Out:
#                                              Total
#                                                sum
# Category Item Desc
# BEVERAGE 2 AXE TWIST                        173.25
#          2 RED BULL                        4083.85
#          3 RED BULL                      100187.63
#          5 RED BULL                       18933.90
#          ADD CARAMEL FLAVOUR               2444.26

# %%
df_1.loc[('BEVERAGE'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                     Total
#                                       sum
# Item Desc
# CAPPUCCINO                      550251.99
# RED BULL 2+1                    378632.29
# RED BULL ENERGY DRINK           373016.12
# LEMON ICED TEA                  282713.79
# BERRY BLAST                     258198.16
# ...                                   ...
# MIXED FLAVOUR SINGLE               297.00
# PEACH BULL                         185.63
# 2 AXE TWIST                        173.25
# DECAFFINATE COFFEE FRAPPE           92.81
# MOCAFE HOT CHOCOLATE(SF)            80.44
#
# [119 rows x 1 columns]

# %%
df_1.loc[('FOOD'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                           Total
#                                             sum
# Item Desc
# GREAT LAKES SHAKE                     843122.11
# JR.CHL AVALANCHE                      713565.60
# POUTINE WITH FRIES                    580284.11
# OREO COOKIE SHAKE                     405644.95
# B.M.T. PANINI                         391066.69
# ...                                         ...
# MUSHROOM & CORN                          216.58
# CHICKEN HAM                              216.55
# CAPONATA                                 185.63
# ADD BUTTERED TOAST                        18.56
# MOTHERS DAY SPL                            0.05
#
# [208 rows x 1 columns]

# %%
df_1.loc[('TOBACCO'),:].size
# Out:
# 52

# %%
df_1.loc[('LIQUOR'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                     Total
#                                       sum
# Item Desc
# CARLSBERG                       538802.08
# TUBORG                          381051.73
# KF DRAUGHT PITCHER (2LTR)       330617.67
# KF DRAUGHT (1LTR)               330073.59
# KF DRAUGHT (1/2LTR)             251396.88
# HOEGAARDEN MUG (1 LITRE)         43378.30
# BUDWEISER                        28298.46
# 1+1 KF 1/2 LITER                 22312.36
# HOEGAARDEN (GLS)                 21065.72
# HOEGAARDEN MUG (1/2 LITRE)       20212.63
# STELLA ARTOIS MUG (1/2 LTR)      15618.84
# 1+1 KF 1 LITER                   14174.92
# STELLA ARTOIS MUG (1 LTR)        12534.43
# BEER TANK 3.5 LITRE              11025.00
# WHITE SANGRIA (GLS)áááá áááááá   10804.50
# STELLA ARTOIS (GLS)               9421.91
# STELLA 1LTR 2+1                   8531.25
# CARLSBERG 2+1                     8250.00
# VODKA (SM)                        7612.50
# TUBORG 2+1                        7471.88
# WHITE SANGRIA (CARAFE)áááááááá    6111.00
# UNLIMITED BEER                    5244.76
# SCHNEIDER BUCKET - 6              4725.00
# BROOKLYN BUCKET - 4               4200.00
# TEQUILA                           3937.50
# 1+1 KF 2 LITER                    3675.00
# ZINZI WHITE  (GLS)                2835.00
# BROOKLYN                          2362.50
# WHITE RUM (SM)                    1837.50
# ZINZI RED (GLS)                   1701.00
# SCHNEIDER WEISSE                  1575.00
# STELLA ARTOIS                     1181.25
# ZINZI WHITE (BTL)                  882.00
# WHISKEY (SM)                       525.00

# %%
df_1.loc[('MERCHANDISE'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                          Total
#                                            sum
# Item Desc
# GREAT LAKES T-SHIRTS                  13351.80
# SANDASS                                9844.88
# FLAVOUR 500 GMS                        6378.75
# CH COFFEE MUGS                         6050.00
# CH TINS                                5842.20
# ...                                        ...
# GREAT LAKES MUG SINGLE                  159.75
# CH WRAPPING PAPER                        90.00
# MUGS - PLAIN COLOUR                      75.38
# DIP BOWL                                 67.50
# CUTTING GLASS                            27.00
#
# [87 rows x 1 columns]

# %%
df_1.loc[('MISC'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                          Total
#                                            sum
# Item Desc
# RED BULL SHEESHA                      61182.00
# PLAIN JANE (CHOCOLATE)                22520.37
# PARTY CHARGES @ 500/-                 14231.25
# ROSE FLAVORS SINGLE                   13068.00
# PLAIN  JANE (STRAWBERRY)              12386.51
# KF DRAFT MUG                          11254.74
# GUAVA                                 10164.00
# ADD ON S                               8469.93
# PLAIN JANES (VANILLA)                  8378.71
# MM SALSA SHEESHA                       7128.00
# ADD HERB ROAST CHICKEN                 6670.13
# ICE BERG SHEESHA                       5940.00
# PAAN SHEESHA                           5568.80
# PEACH BULL                             2413.17
# ADD POTATO WEDGES                      1763.39
# HOEGAARDEN LTR MUGS (2+1)              1706.25
# GREAT LAKES STAMP DAIRY                1124.55
# RED SANGRIA (CARAFE) áááááááá          1008.00
# HOEGAARDEN GLS (2+1)                    918.75
# GIN (SM)                                787.50
# DARK RUM (SM)                           787.50
# FISH FINGER                             742.50
# GRAPPO SHEESHA                          594.00
# LEMON INFUSED CHAR GRILLED VEG          587.82
# 1 AXE TWIST                             519.78
# ADD TRADITIONAL MEAT FEAST              501.21
# ROAST CHICKEN SALAD                     482.62
# ITALIAN CAPONATA PANINO                 464.06
# QUESO CROQUETAS FRITOS                  445.50
# POLLO CON AIOLI                         445.50
# PHILADELPHIA CREAM CHEESECAKE           383.62
# ORANGE ARRABIATA                        371.26
# HOTDOG WRAP                             371.26
# GREEK GYROS CRUSTINI                    358.88
# ENG BREAKFAST TEA                       340.31
# NUTELLA CREPES                          321.76
# RED BULL 2+1                            309.38
# MANGO FLAVOUR SINGLE                    297.00
# MEDITER RANEAN PANINO                   259.88
# POLLO PELOTA CON TAMATE SALSA           235.13
# M & M SHAKE                             222.75
# MEXICAN CHILLY CREPES                   204.19
# JAPANESE YAKITORI WRAP                  185.63
# GNOCCHI CON POMMODORO                   185.63
# ROMA TOMATO & JALAPENO CROQUE           154.69
# ADD CHICKEN BACON                       148.52
# RASPBERRY LITE SHAKE                    142.31
# ADD GROUND MEAT                         111.39

# %%
df_1.loc[('WINES'),:].size
# Out:
# 50

# %%
df_1.loc[('LIQUOR & TOBACCO'),:].sort_values(('Total', 'sum'), ascending=False)
# Out:
#                                    Total
#                                      sum
# Item Desc
# BEER HOOKAH                     32324.00
# 2 DOM BEER + 1SPL SHEESHA        6562.50
# 4 DOM BEER + 1SPL SHEESHA        1968.76
# 2 DOM BEER + 1PREM SHEESHA       1706.26

# %%
fig, axes = plt.subplots(nrows=3,ncols=2)
fig.set_size_inches(10, 15)
a = sns.distplot(df['Quantity'] , ax=axes[0][0])
a.set_title("Quantity",fontsize=10)
a = sns.distplot(df['Rate'] , ax=axes[0][1])
a.set_title("Rate",fontsize=10)
a = sns.distplot(df['Tax'] , ax=axes[1][0])
a.set_title("Tax",fontsize=10)
a = sns.distplot(df['Discount'] , ax=axes[1][1])
a.set_title("Discount",fontsize=10)
a = sns.distplot(df['Total'] , ax=axes[2][0])
a.set_title("Total",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Total')

# %%
# Check for outliers
plt.figure(figsize=(10,10))
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
corr=df.corr()

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(corr, annot=True) 
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (5.5, -0.5)

# %% [raw]
# Interestingly we notice a weak correlation between Total sales and Discounts.

# %% [raw]
# Customer segmentation using K-means Cluster

# %%
kmdf=pd.read_excel("Cafe_Data_MRA.xlsx")

# %%
kmdf.drop_duplicates(inplace=True)

# %%
dups=kmdf.duplicated().sum()
dups
# Out:
# 0

# %%
kmdf.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
# Outlier Treatment
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
lrRate,urRate=remove_outlier(kmdf['Rate'])
kmdf['Rate']=np.where(kmdf['Rate']>urRate,urRate,kmdf['Rate'])
kmdf['Rate']=np.where(kmdf['Rate']<lrRate,lrRate,kmdf['Rate'])
lrTax,urTax=remove_outlier(kmdf['Tax'])
kmdf['Tax']=np.where(kmdf['Tax']>urTax,urTax,kmdf['Tax'])
kmdf['Tax']=np.where(kmdf['Tax']<lrTax,lrTax,kmdf['Tax'])
lrDiscount,urDiscount=remove_outlier(kmdf['Discount'])
kmdf['Discount']=np.where(kmdf['Discount']>urDiscount,urDiscount,kmdf['Discount'])
kmdf['Discount']=np.where(kmdf['Discount']<lrDiscount,lrDiscount,kmdf['Discount'])
lrTotal,urTotal=remove_outlier(kmdf['Total'])
kmdf['Total']=np.where(kmdf['Total']>urTotal,urTotal,kmdf['Total'])
kmdf['Total']=np.where(kmdf['Total']<lrTotal,lrTotal,kmdf['Total'])
lrQuantity,urQuantity=remove_outlier(kmdf['Quantity'])
kmdf['Quantity']=np.where(kmdf['Quantity']>urQuantity,urQuantity,kmdf['Quantity'])
kmdf['Quantity']=np.where(kmdf['Quantity']<lrQuantity,lrQuantity,kmdf['Quantity'])

# %%
# Check for outliers
plt.figure(figsize=(10,10))
kmdf.boxplot()
# Out:
# <AxesSubplot:>

# %% [raw]
# Market Basket Analysis using association rule:

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
from sklearn import set_config
set_config(print_changed_only=False)

# %%
df.columns
# Out:
# Index(['Date', 'Bill Number ', 'Item Desc', 'Time', 'Quantity', 'Rate', 'Tax',
#        'Discount', 'Total', 'Category'],
#       dtype='object')

# %%
df.head()
# Out:
#         Date Bill Number                        Item Desc      Time  Quantity  \
# 0 2010-04-01     G0470115  QUA  MINERAL WATER(1000ML)      13:15:11         1
# 1 2010-04-01     G0470115  MONSOON MALABAR (AULAIT)        13:15:11         1
# 2 2010-04-01     G0470116  MASALA CHAI CUTTING             13:17:35         1
# 3 2010-04-01     G0470117  QUA  MINERAL WATER(1000ML)      13:19:55         1
# 4 2010-04-01     G0470283  MOROCCAN MINT TEA               01:20:18         1
#
#     Rate    Tax  Discount   Total  Category
# 0   50.0  11.88       0.0   61.88  BEVERAGE
# 1  100.0  23.75       0.0  123.75  BEVERAGE
# 2   40.0   9.50       0.0   49.50  BEVERAGE
# 3   50.0  11.88       0.0   61.88  BEVERAGE
# 4   45.0  10.69       0.0   55.69  BEVERAGE

# %%
df.groupby(['Bill Number ','Item Desc'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('Bill Number ')
# Out:
# Item Desc     1 AXE TWIST                     1+1 BTL4 SEASON WHITE           \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     1+1 GLS 4SEASON RED             1+1 GLS 4SEASONS WHITE          \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     1+1 KF 1 LITER                  1+1 KF 1/2 LITER                \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     1+1 KF 2 LITER                  1+1 VLN CAB SAUV (BTL)          \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     1+1 VLN CAB SAUV (GLS)          1+1 VLN CAB SAUV CLASIQ (BTL)   \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     ...  WHITE WINE SHEESHA              \
# Bill Number   ...
# G0470109      ...                             0.0
# G0470110      ...                             0.0
# G0470111      ...                             0.0
# G0470112      ...                             0.0
# G0470113      ...                             0.0
# ...           ...                             ...
# N0034042      ...                             0.0
# N0034043      ...                             0.0
# N0034044      ...                             0.0
# N0034045      ...                             0.0
# N0034046      ...                             0.0
#
# Item Desc     WILD MUSHROOM LINGUINI          \
# Bill Number
# G0470109                                 0.0
# G0470110                                 0.0
# G0470111                                 0.0
# G0470112                                 0.0
# G0470113                                 0.0
# ...                                      ...
# N0034042                                 0.0
# N0034043                                 0.0
# N0034044                                 0.0
# N0034045                                 0.0
# N0034046                                 0.0
#
# Item Desc     YEMENI GREAT LAKES (AULAIT)           \
# Bill Number
# G0470109                                       0.0
# G0470110                                       0.0
# G0470111                                       0.0
# G0470112                                       0.0
# G0470113                                       0.0
# ...                                            ...
# N0034042                                       0.0
# N0034043                                       0.0
# N0034044                                       0.0
# N0034045                                       0.0
# N0034046                                       0.0
#
# Item Desc     YEMENI GREAT LAKES (REG)              \
# Bill Number
# G0470109                                       0.0
# G0470110                                       0.0
# G0470111                                       0.0
# G0470112                                       0.0
# G0470113                                       0.0
# ...                                            ...
# N0034042                                       0.0
# N0034043                                       0.0
# N0034044                                       0.0
# N0034045                                       0.0
# N0034046                                       0.0
#
# Item Desc     YIN N YANG FONDUE               ZEN ROCK SQUARE VASE            \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     ZERO SIZE SHOT GLS              ZINZI RED (GLS)                 \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# Item Desc     ZINZI WHITE  (GLS)              ZINZI WHITE (BTL)
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
# ...                                      ...                             ...
# N0034042                                 0.0                             0.0
# N0034043                                 0.0                             0.0
# N0034044                                 0.0                             0.0
# N0034045                                 0.0                             0.0
# N0034046                                 0.0                             0.0
#
# [69982 rows x 580 columns]

# %%
df_1=df.groupby(['Bill Number ','Item Desc'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('Bill Number ')

# %%
df_1.head()
# Out:
# Item Desc     1 AXE TWIST                     1+1 BTL4 SEASON WHITE           \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     1+1 GLS 4SEASON RED             1+1 GLS 4SEASONS WHITE          \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     1+1 KF 1 LITER                  1+1 KF 1/2 LITER                \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     1+1 KF 2 LITER                  1+1 VLN CAB SAUV (BTL)          \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     1+1 VLN CAB SAUV (GLS)          1+1 VLN CAB SAUV CLASIQ (BTL)   \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     ...  WHITE WINE SHEESHA              \
# Bill Number   ...
# G0470109      ...                             0.0
# G0470110      ...                             0.0
# G0470111      ...                             0.0
# G0470112      ...                             0.0
# G0470113      ...                             0.0
#
# Item Desc     WILD MUSHROOM LINGUINI          \
# Bill Number
# G0470109                                 0.0
# G0470110                                 0.0
# G0470111                                 0.0
# G0470112                                 0.0
# G0470113                                 0.0
#
# Item Desc     YEMENI GREAT LAKES (AULAIT)           \
# Bill Number
# G0470109                                       0.0
# G0470110                                       0.0
# G0470111                                       0.0
# G0470112                                       0.0
# G0470113                                       0.0
#
# Item Desc     YEMENI GREAT LAKES (REG)              \
# Bill Number
# G0470109                                       0.0
# G0470110                                       0.0
# G0470111                                       0.0
# G0470112                                       0.0
# G0470113                                       0.0
#
# Item Desc     YIN N YANG FONDUE               ZEN ROCK SQUARE VASE            \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     ZERO SIZE SHOT GLS              ZINZI RED (GLS)                 \
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# Item Desc     ZINZI WHITE  (GLS)              ZINZI WHITE (BTL)
# Bill Number
# G0470109                                 0.0                             0.0
# G0470110                                 0.0                             0.0
# G0470111                                 0.0                             0.0
# G0470112                                 0.0                             0.0
# G0470113                                 0.0                             0.0
#
# [5 rows x 580 columns]

# %%
df_1.shape
# Out:
# (69982, 580)

# %%
# Encoding the data to make it binary. For Market Basket analysis, the presence of an item is given more importance
#than the total quantities present. We equate anything less than 0 to 0 and make values greater than 1 as 1

def encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# %%
dt=df_1.applymap(encode) #mapping the above user defined function

# %%
dt.head()
# Out:
# Item Desc     1 AXE TWIST                     1+1 BTL4 SEASON WHITE           \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     1+1 GLS 4SEASON RED             1+1 GLS 4SEASONS WHITE          \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     1+1 KF 1 LITER                  1+1 KF 1/2 LITER                \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     1+1 KF 2 LITER                  1+1 VLN CAB SAUV (BTL)          \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     1+1 VLN CAB SAUV (GLS)          1+1 VLN CAB SAUV CLASIQ (BTL)   \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     ...  WHITE WINE SHEESHA              \
# Bill Number   ...
# G0470109      ...                               0
# G0470110      ...                               0
# G0470111      ...                               0
# G0470112      ...                               0
# G0470113      ...                               0
#
# Item Desc     WILD MUSHROOM LINGUINI          \
# Bill Number
# G0470109                                   0
# G0470110                                   0
# G0470111                                   0
# G0470112                                   0
# G0470113                                   0
#
# Item Desc     YEMENI GREAT LAKES (AULAIT)           \
# Bill Number
# G0470109                                         0
# G0470110                                         0
# G0470111                                         0
# G0470112                                         0
# G0470113                                         0
#
# Item Desc     YEMENI GREAT LAKES (REG)              \
# Bill Number
# G0470109                                         0
# G0470110                                         0
# G0470111                                         0
# G0470112                                         0
# G0470113                                         0
#
# Item Desc     YIN N YANG FONDUE               ZEN ROCK SQUARE VASE            \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     ZERO SIZE SHOT GLS              ZINZI RED (GLS)                 \
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# Item Desc     ZINZI WHITE  (GLS)              ZINZI WHITE (BTL)
# Bill Number
# G0470109                                   0                               0
# G0470110                                   0                               0
# G0470111                                   0                               0
# G0470112                                   0                               0
# G0470113                                   0                               0
#
# [5 rows x 580 columns]

# %%
itemsets = apriori(dt, min_support = 0.002, use_colnames = True,low_memory=True)
itemsets.sort_values('support',ascending=False,inplace=True)
itemsets
# Out:
#       support                                           itemsets
# 96   0.119874                   (NIRVANA HOOKAH SINGLE         )
# 88   0.083050                   (MINT FLAVOUR SINGLE           )
# 27   0.078134                   (CAPPUCCINO                    )
# 57   0.069604             (GREAT LAKES SHAKE                   )
# 117  0.063202                   (SAMBUCA                       )
# ..        ...                                                ...
# 226  0.002015  (RED BULL ENERGY DRINK         , N R G  HOOKAH...
# 90   0.002015                   (MIXED FLAVOUR SINGLE          )
# 154  0.002015  (COTTAGE CHEESE PANINI         , B.M.T. PANINI...
# 194  0.002015  (POUTINE WITH FRIES            , COUNTRY LEMON...
# 185  0.002015  (CAPPUCCINO                    , PHILLYCREAM C...
#
# [242 rows x 2 columns]

# %%
plt.figure(figsize=(12,7))
sns.barplot(itemsets.sort_values('support',ascending=False).iloc[0:20,1],
            itemsets.sort_values('support',ascending=False).iloc[0:20,0])
plt.xticks(rotation=90)
plt.show()

# %%
# Association Rules
basket = association_rules(itemsets, metric='lift',min_threshold=0.1)

# %%
basket
# Out:
#                           antecedents                             consequents  \
# 0    (NIRVANA HOOKAH SINGLE         )        (POUTINE WITH FRIES            )
# 1    (POUTINE WITH FRIES            )        (NIRVANA HOOKAH SINGLE         )
# 2    (CAPPUCCINO                    )        (MINT FLAVOUR SINGLE           )
# 3    (MINT FLAVOUR SINGLE           )        (CAPPUCCINO                    )
# 4    (CAPPUCCINO                    )  (GREAT LAKES SHAKE                   )
# ..                                ...                                     ...
# 179  (COTTAGE CHEESE PANINI         )        (B.M.T. PANINI                 )
# 180  (COUNTRY LEMONADE              )        (POUTINE WITH FRIES            )
# 181  (POUTINE WITH FRIES            )        (COUNTRY LEMONADE              )
# 182  (CAPPUCCINO                    )        (PHILLYCREAM CHEESE &CHILLY PAN)
# 183  (PHILLYCREAM CHEESE &CHILLY PAN)        (CAPPUCCINO                    )
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.119874            0.048784  0.006330    0.052807  1.082471
# 1              0.048784            0.119874  0.006330    0.129760  1.082471
# 2              0.078134            0.083050  0.005987    0.076628  0.922670
# 3              0.083050            0.078134  0.005987    0.072092  0.922670
# 4              0.078134            0.069604  0.005544    0.070958  1.019463
# ..                  ...                 ...       ...         ...       ...
# 179            0.023034            0.037224  0.002015    0.087469  2.349810
# 180            0.025850            0.048784  0.002015    0.077944  1.597730
# 181            0.048784            0.025850  0.002015    0.041301  1.597730
# 182            0.078134            0.026578  0.002015    0.025786  0.970206
# 183            0.026578            0.078134  0.002015    0.075806  0.970206
#
#      leverage  conviction  zhangs_metric
# 0    0.000482    1.004248       0.086565
# 1    0.000482    1.011360       0.080095
# 2   -0.000502    0.993045      -0.083338
# 3   -0.000502    0.993488      -0.083748
# 4    0.000106    1.001458       0.020709
# ..        ...         ...            ...
# 179  0.001157    1.055061       0.587977
# 180  0.000754    1.031625       0.384039
# 181  0.000754    1.016117       0.393299
# 182 -0.000062    0.999187      -0.032238
# 183 -0.000062    0.997481      -0.030582
#
# [184 rows x 10 columns]

# %%
basket = basket.sort_values(['lift'], ascending =[False])

# %%
basket.head(50)
# Out:
#                                 antecedents  \
# 154        (B.M.T. PANINI                 )
# 155        (ADD FRIES                     )
# 26         (SAMBUCA                       )
# 27         (RED BULL 2+1                  )
# 91         (MAGGI NDL ARRABIATA           )
# 90         (SAMBUCA                       )
# 112        (CALCUTTA MINT                 )
# 113        (RED BULL 2+1                  )
# 78         (B.M.T. PANINI                 )
# 79         (PHILLYCREAM CHEESE &CHILLY PAN)
# 30         (SAMBUCA                       )
# 31         (RED BULL ENERGY DRINK         )
# 176        (N R G  HOOKAH                 )
# 177        (RED BULL ENERGY DRINK         )
# 161        (B.M.T. PANINI                 )
# 160        (KIT KAT SHAKE                 )
# 178        (B.M.T. PANINI                 )
# 179        (COTTAGE CHEESE PANINI         )
# 65         (CALCUTTA MINT                 )
# 64         (RED BULL ENERGY DRINK         )
# 63         (POUTINE WITH FRIES            )
# 62         (PHILLYCREAM CHEESE &CHILLY PAN)
# 115        (COTTAGE CHEESE PANINI         )
# 114        (POUTINE WITH FRIES            )
# 36         (B.M.T. PANINI                 )
# 37         (POUTINE WITH FRIES            )
# 40         (B.M.T. PANINI                 )
# 41         (QUA  MINERAL WATER(1000ML)    )
# 14         (SAMBUCA                       )
# 15         (B.M.T. PANINI                 )
# 174        (B.M.T. PANINI                 )
# 175        (BERRY BLAST                   )
# 137  (GREAT LAKES SHAKE                   )
# 136        (GARDEN FRESH PANINI           )
# 69         (QUA  MINERAL WATER(1000ML)    )
# 68         (MOROCCAN MINT TEA             )
# 23         (CAFFE LATTE                   )
# 22         (CAPPUCCINO                    )
# 164        (B.M.T. PANINI                 )
# 165        (LEMON ICED TEA                )
# 105        (OREO COOKIE SHAKE             )
# 104        (POUTINE WITH FRIES            )
# 166        (B.M.T. PANINI                 )
# 167        (N R G  HOOKAH                 )
# 55         (CALCUTTA MINT                 )
# 54         (B.M.T. PANINI                 )
# 107        (QUA  MINERAL WATER(500ML)     )
# 106        (NIRVANA HOOKAH SINGLE         )
# 86         (POUTINE WITH FRIES            )
# 87         (LEMON ICED TEA                )
#
#                                 consequents  antecedent support  \
# 154        (ADD FRIES                     )            0.037224
# 155        (B.M.T. PANINI                 )            0.010746
# 26         (RED BULL 2+1                  )            0.063202
# 27         (SAMBUCA                       )            0.016676
# 91         (SAMBUCA                       )            0.012589
# 90         (MAGGI NDL ARRABIATA           )            0.063202
# 112        (RED BULL 2+1                  )            0.047255
# 113        (CALCUTTA MINT                 )            0.016676
# 78         (PHILLYCREAM CHEESE &CHILLY PAN)            0.037224
# 79         (B.M.T. PANINI                 )            0.026578
# 30         (RED BULL ENERGY DRINK         )            0.063202
# 31         (SAMBUCA                       )            0.026578
# 176        (RED BULL ENERGY DRINK         )            0.031937
# 177        (N R G  HOOKAH                 )            0.026578
# 161        (KIT KAT SHAKE                 )            0.037224
# 160        (B.M.T. PANINI                 )            0.023992
# 178        (COTTAGE CHEESE PANINI         )            0.037224
# 179        (B.M.T. PANINI                 )            0.023034
# 65         (RED BULL ENERGY DRINK         )            0.047255
# 64         (CALCUTTA MINT                 )            0.026578
# 63         (PHILLYCREAM CHEESE &CHILLY PAN)            0.048784
# 62         (POUTINE WITH FRIES            )            0.026578
# 115        (POUTINE WITH FRIES            )            0.023034
# 114        (COTTAGE CHEESE PANINI         )            0.048784
# 36         (POUTINE WITH FRIES            )            0.037224
# 37         (B.M.T. PANINI                 )            0.048784
# 40         (QUA  MINERAL WATER(1000ML)    )            0.037224
# 41         (B.M.T. PANINI                 )            0.047555
# 14         (B.M.T. PANINI                 )            0.063202
# 15         (SAMBUCA                       )            0.037224
# 174        (BERRY BLAST                   )            0.037224
# 175        (B.M.T. PANINI                 )            0.029022
# 137        (GARDEN FRESH PANINI           )            0.069604
# 136  (GREAT LAKES SHAKE                   )            0.017647
# 69         (MOROCCAN MINT TEA             )            0.047555
# 68         (QUA  MINERAL WATER(1000ML)    )            0.032237
# 23         (CAPPUCCINO                    )            0.029936
# 22         (CAFFE LATTE                   )            0.078134
# 164        (LEMON ICED TEA                )            0.037224
# 165        (B.M.T. PANINI                 )            0.031337
# 105        (POUTINE WITH FRIES            )            0.028422
# 104        (OREO COOKIE SHAKE             )            0.048784
# 166        (N R G  HOOKAH                 )            0.037224
# 167        (B.M.T. PANINI                 )            0.031937
# 55         (B.M.T. PANINI                 )            0.047255
# 54         (CALCUTTA MINT                 )            0.037224
# 107        (NIRVANA HOOKAH SINGLE         )            0.011903
# 106        (QUA  MINERAL WATER(500ML)     )            0.119874
# 86         (LEMON ICED TEA                )            0.048784
# 87         (POUTINE WITH FRIES            )            0.031337
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 154            0.010746  0.002158    0.057965  5.394333  0.001758    1.050125
# 155            0.037224  0.002158    0.200798  5.394333  0.001758    1.204672
# 26             0.016676  0.004144    0.065566  3.931846  0.003090    1.052321
# 27             0.063202  0.004144    0.248500  3.931846  0.003090    1.246572
# 91             0.063202  0.002501    0.198638  3.142907  0.001705    1.169007
# 90             0.012589  0.002501    0.039566  3.142907  0.001705    1.028088
# 112            0.016676  0.002372    0.050197  3.010159  0.001584    1.035292
# 113            0.047255  0.002372    0.142245  3.010159  0.001584    1.110743
# 78             0.026578  0.002615    0.070250  2.643119  0.001626    1.046971
# 79             0.037224  0.002615    0.098387  2.643119  0.001626    1.067838
# 30             0.026578  0.004044    0.063984  2.407370  0.002364    1.039962
# 31             0.063202  0.004044    0.152151  2.407370  0.002364    1.104911
# 176            0.026578  0.002015    0.063087  2.373641  0.001166    1.038967
# 177            0.031937  0.002015    0.075806  2.373641  0.001166    1.047468
# 161            0.023992  0.002115    0.056814  2.368043  0.001222    1.034799
# 160            0.037224  0.002115    0.088148  2.368043  0.001222    1.055847
# 178            0.023034  0.002015    0.054127  2.349810  0.001157    1.032871
# 179            0.037224  0.002015    0.087469  2.349810  0.001157    1.055061
# 65             0.026578  0.002844    0.060175  2.264083  0.001588    1.035748
# 64             0.047255  0.002844    0.106989  2.264083  0.001588    1.066891
# 63             0.026578  0.002886    0.059168  2.226185  0.001590    1.034639
# 62             0.048784  0.002886    0.108602  2.226185  0.001590    1.067106
# 115            0.048784  0.002358    0.102357  2.098175  0.001234    1.059682
# 114            0.023034  0.002358    0.048330  2.098175  0.001234    1.026581
# 36             0.048784  0.003801    0.102111  2.093133  0.001985    1.059392
# 37             0.037224  0.003801    0.077914  2.093133  0.001985    1.044129
# 40             0.047555  0.003672    0.098656  2.074572  0.001902    1.056695
# 41             0.037224  0.003672    0.077224  2.074572  0.001902    1.043347
# 14             0.037224  0.004687    0.074158  1.992212  0.002334    1.039892
# 15             0.063202  0.004687    0.125912  1.992212  0.002334    1.071743
# 174            0.029022  0.002015    0.054127  1.865039  0.000935    1.026542
# 175            0.037224  0.002015    0.069424  1.865039  0.000935    1.034602
# 137            0.017647  0.002286    0.032847  1.861321  0.001058    1.015716
# 136            0.069604  0.002286    0.129555  1.861321  0.001058    1.068874
# 69             0.032237  0.002815    0.059195  1.836243  0.001282    1.028654
# 68             0.047555  0.002815    0.087323  1.836243  0.001282    1.043572
# 23             0.078134  0.004244    0.141766  1.814388  0.001905    1.074143
# 22             0.029936  0.004244    0.054316  1.814388  0.001905    1.025780
# 164            0.031337  0.002086    0.056046  1.788516  0.000920    1.026177
# 165            0.037224  0.002086    0.066575  1.788516  0.000920    1.031445
# 105            0.048784  0.002401    0.084465  1.731400  0.001014    1.038972
# 104            0.028422  0.002401    0.049209  1.731400  0.001014    1.021863
# 166            0.031937  0.002043    0.054894  1.718847  0.000855    1.024291
# 167            0.037224  0.002043    0.063982  1.718847  0.000855    1.028587
# 55             0.037224  0.003015    0.063804  1.714063  0.001256    1.028392
# 54             0.047255  0.003015    0.080998  1.714063  0.001256    1.036717
# 107            0.119874  0.002401    0.201681  1.682443  0.000974    1.102474
# 106            0.011903  0.002401    0.020026  1.682443  0.000974    1.008289
# 86             0.031337  0.002529    0.051845  1.654465  0.001000    1.021630
# 87             0.048784  0.002529    0.080711  1.654465  0.001000    1.034731
#
#      zhangs_metric
# 154       0.846116
# 155       0.823469
# 26        0.795974
# 27        0.758312
# 91        0.690516
# 90        0.727823
# 112       0.700913
# 113       0.679116
# 78        0.645694
# 79        0.638633
# 30        0.624050
# 31        0.600571
# 176       0.597798
# 177       0.594507
# 161       0.600046
# 160       0.591911
# 178       0.596643
# 179       0.587977
# 65        0.586012
# 64        0.573564
# 63        0.579049
# 62        0.565840
# 115       0.535736
# 114       0.550238
# 36        0.542439
# 37        0.549031
# 40        0.537999
# 41        0.543835
# 14        0.531646
# 15        0.517301
# 174       0.481751
# 175       0.477681
# 137       0.497366
# 136       0.471060
# 69        0.478148
# 68        0.470580
# 23        0.462702
# 22        0.486893
# 164       0.457923
# 165       0.455140
# 105       0.434790
# 104       0.444097
# 166       0.434384
# 167       0.432012
# 55        0.437253
# 54        0.432698
# 107       0.410513
# 106       0.460873
# 86        0.415862
# 87        0.408372

# %%
basket.shape
# Out:
# (184, 10)

# %%
results_df = pd.DataFrame(basket)
results_df.to_excel('basket_MRA_4.xlsx',index=False)
